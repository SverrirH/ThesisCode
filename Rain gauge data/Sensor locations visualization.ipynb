# %%
import pandas as pd
import numpy as np
from glob import glob

DIR_rain_data = '../../Data/Rain gauges/'
DIR_rain_gauge = DIR_rain_data + 'hbs_lysigogn.csv'

# %%
df_meta = pd.read_csv(DIR_rain_gauge,
                      sep='\t',
                      encoding='Windows-1252')

# %%
df_meta.columns
# Out:
# Index(['STOD', 'YFIRSTOD', 'STOD_WMO', 'NAFN', 'NAFN_ST', 'SKST', 'SPASV',
#        'TEG', 'LANDS_NR', 'LANDS_SK', 'BREIDD', 'LENGD', 'BREIDD_Y', 'LENGD_X',
#        'H_STOD', 'H_LOFTVOG', 'H_HITAM', 'H_VINDM', 'H_URKM', 'TH_HRODUN',
#        'EIG', 'EIG_NR', 'FYRND', 'UPPHAF', 'ENDIR', 'ATHS', 'SK_FNG',
#        'SK_TIMI', 'BR_FNG', 'BR_TIMI'],
#       dtype='object')

# %%
Sensors = [{'Nafn':"Fíflholt á Mýrum",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"1868",
'WMO-númer':"4914",
'Skammstöfun':"fiflh",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°41.659', 22°08.840' (64,6943, 22,1473)",
'Hæð yfir sjó':"40.0 m.y.s.",
'Upphaf veðurathuguna':"2006",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Garðabær - Urriðaholt",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"1474",
'WMO-númer':"-99",
'Skammstöfun':"uholt",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°4.270, 21°54.640 (64,0712, 21,9107)",
'Hæð yfir sjó':"37.0 m.y.s.",
'Upphaf veðurathuguna':"2019",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Hellisskarð",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"1490",
'WMO-númer':"4862",
'Skammstöfun':"hells",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°02.000', 21°21.992' (64,0333, 21,3665)",
'Hæð yfir sjó':"380.0 m.y.s.",
'Upphaf veðurathuguna':"2001",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Hvanneyri",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"1779",
'WMO-númer':"4134",
'Skammstöfun':"hveyr",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°33,732', 21°45,896' (64,5622, 21,7649)",
'Hæð yfir sjó':"12.399999618530273 m.y.s.",
'Upphaf veðurathuguna':"1997",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Hvassahraun",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"1370",
'WMO-númer':"4824",
'Skammstöfun':"hvass",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°01.181', 22°05.513' (64,0197, 22,0919)",
'Hæð yfir sjó':"41.0 m.y.s.",
'Upphaf veðurathuguna':"2001",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Hólmsheiði",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"1481",
'WMO-númer':"4920",
'Skammstöfun':"holms",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°06.510', 21°41.182' (64,1085, 21,6864)",
'Hæð yfir sjó':"130.0 m.y.s.",
'Upphaf veðurathuguna':"2006",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Reykjavík búveðurstöð",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"7475",
'WMO-númer':"4930",
'Skammstöfun':"reits",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°07.646', 21°54.146' (64,1274, 21,9024)",
'Hæð yfir sjó':"52.0 m.y.s.",
'Upphaf veðurathuguna':"2000",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Reykjavík Geirsnef",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"1478",
'WMO-númer':"-99",
'Skammstöfun':"genef",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°07.755', 21°50.351' (64,1292, 21,8392)",
'Hæð yfir sjó':"4.0 m.y.s.",
'Upphaf veðurathuguna':"2019",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Reykjavík Háahlíð",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"1470",
'WMO-númer':"-99",
'Skammstöfun':"reith",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°07.730', 21°54.493' (64,1288, 21,9082)",
'Hæð yfir sjó':"60.20000076293945 m.y.s.",
'Upphaf veðurathuguna':"2021",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Reykjavík Víðidalur",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"1482",
'WMO-númer':"-99",
'Skammstöfun':"vidal",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°06.208, 21°47.825 (64,1035, 21,7971)",
'Hæð yfir sjó':"71.0 m.y.s.",
'Upphaf veðurathuguna':"2018",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Reykjavík búveðurstöð",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"7475",
'WMO-númer':"4930",
'Skammstöfun':"reits",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°07.646', 21°54.146' (64,1274, 21,9024)",
'Hæð yfir sjó':"52.0 m.y.s.",
'Upphaf veðurathuguna':"2000",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Skrauthólar",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"1578",
'WMO-númer':"4818",
'Skammstöfun':"skrau",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°13.909', 21°48.278' (64,2318, 21,8046)",
'Hæð yfir sjó':"20.0 m.y.s.",
'Upphaf veðurathuguna':"2001",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Straumsvík",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"1473",
'WMO-númer':"4124",
'Skammstöfun':"strau",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°02.628', 22°02.427' (64,0438, 22,0404)",
'Hæð yfir sjó':"7.0 m.y.s.",
'Upphaf veðurathuguna':"2001",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Ölkelduháls",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"1493",
'WMO-númer':"4864",
'Skammstöfun':"olkel",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°03.317', 21°15.190' (64,0553, 21,2532)",
'Hæð yfir sjó':"360.0 m.y.s.",
'Upphaf veðurathuguna':"2001",
'Eigandi stöðvar':"Veðurstofa Íslands",},

{'Nafn':"Reykjavík búveðurstöð",
'Tegund':"Sjálfvirk veðurathugunarstöð",
'Stöðvanúmer':"7475",
'WMO-númer':"4930",
'Skammstöfun':"reits",
'Spásvæði':"Faxaflói(fa)",
'Staðsetning':"64°07.646', 21°54.146' (64,1274, 21,9024)",
'Hæð yfir sjó':"52.0 m.y.s.",
'Upphaf veðurathuguna':"2000",
'Eigandi stöðvar':"Veðurstofa Íslands",},
]

# %%
# Out:
# 0     22.1473
# 1     21.9107
# 2     21.3665
# 3     21.7649
# 4     22.0919
# 5     21.6864
# 6     21.9024
# 7     21.8392
# 8     21.9082
# 9     21.7971
# 10    21.9024
# 11    21.8046
# 12    22.0404
# 13    21.2532
# 14    21.9024
# Name: Staðsetning, dtype: float64

# %%
import pandas as pd
import numpy as np
df_sensors = pd.DataFrame(Sensors)

df_sensors.loc[:,'y'] = df_sensors.loc[:,'Staðsetning'].apply(lambda x : x[-17:-10]).str.replace(',','.').astype(float)
df_sensors.loc[:,'x'] = df_sensors.loc[:,'Staðsetning'].apply(lambda x : x[-8:-1]).str.replace(',','.').astype(float)

# %%
URL_gauge_data = 'C:/Users/sverrirhd/Google Drive/Skóli/DTU/Thesis/Data/Rain gauges/'
URL_save_sensor_data = URL_gauge_data + 'sensor_info'
df_sensors.to_pickle(URL_save_sensor_data)

# %%
df_sensors
# Out:
#                      Nafn                        Tegund Stöðvanúmer WMO-númer  \
# 0        Fíflholt á Mýrum  Sjálfvirk veðurathugunarstöð        1868      4914
# 1   Garðabær - Urriðaholt  Sjálfvirk veðurathugunarstöð        1474       -99
# 2             Hellisskarð  Sjálfvirk veðurathugunarstöð        1490      4862
# 3               Hvanneyri  Sjálfvirk veðurathugunarstöð        1779      4134
# 4             Hvassahraun  Sjálfvirk veðurathugunarstöð        1370      4824
# 5              Hólmsheiði  Sjálfvirk veðurathugunarstöð        1481      4920
# 6   Reykjavík búveðurstöð  Sjálfvirk veðurathugunarstöð        7475      4930
# 7      Reykjavík Geirsnef  Sjálfvirk veðurathugunarstöð        1478       -99
# 8       Reykjavík Háahlíð  Sjálfvirk veðurathugunarstöð        1470       -99
# 9     Reykjavík Víðidalur  Sjálfvirk veðurathugunarstöð        1482       -99
# 10  Reykjavík búveðurstöð  Sjálfvirk veðurathugunarstöð        7475      4930
# ...

# %%
import folium
mapit = folium.Map( location=[64.021, -22.655], zoom_start=6 )

for index,row in df_sensors.iterrows():
    x_tmp,y_tmp = row['x'],row['y']
    folium.Marker( location = [y_tmp,x_tmp]).add_to( mapit )

# folium.Circle([64.021, -22.655],radius = 250_000).add_to( mapit )
folium.Circle([64.021, -22.655],radius = 240_000).add_to( mapit )
folium.Circle([64.021, -22.655],radius = 160_000).add_to( mapit )
folium.Circle([64.021, -22.655],radius = 80_000).add_to( mapit )
folium.Circle([64.021, -22.655],radius = 1000).add_to( mapit )

mapit.save( 'map.html')
